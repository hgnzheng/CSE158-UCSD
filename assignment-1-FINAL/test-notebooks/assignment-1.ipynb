# %%
import gzip
from collections import defaultdict
import math
import scipy.optimize
from sklearn import svm
from sklearn import linear_model
import numpy as np
import string
import random
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
def assertFloat(x):
    assert type(float(x)) == float

def assertFloatList(items, N):
    assert len(items) == N
    assert [type(float(x)) for x in items] == [float]*N

# %%
def readGz(path):
    for l in gzip.open(path, 'rt'):
        yield eval(l)

# %%
def readJSON(path):
    f = gzip.open(path, 'rt')
    f.readline()
    for l in f:
        d = eval(l)
        u = d['userID']
        g = d['gameID']
        yield u,g,d

# %%
answers = {}

# %%
# Some data structures that will be useful

# %%
allHours = []
for l in readJSON("train.json.gz"):
    allHours.append(l)

# %%
hoursTrain = allHours[:165000]
hoursValid = allHours[165000:]

# %%
hoursPerUser = defaultdict(list)
hoursPerItem = defaultdict(list)
for u,g,d in hoursTrain:
    r = d['hours_transformed']
    hoursPerUser[u].append((g, r))
    hoursPerItem[g].append((u, r))

# %%
itemsPerUser = defaultdict(list)
usersPerItem = defaultdict(list)
for u,g,d in hoursTrain:
    itemsPerUser[u].append(g)
    usersPerItem[g].append(u)

# %%
userIDs, itemIDs = {}, {}
interactions = []

for u,g,d in allHours:
    r = d['hours_transformed']
    if not u in userIDs: userIDs[u] = len(userIDs)
    if not g in itemIDs: itemIDs[g] = len(itemIDs)
    interactions.append((u,g,r))

# %%
##################################################
# Play prediction                                #
##################################################

# %%
# Generate a negative set
userSet = set()
gameSet = set()
playedSet = set()

for u,g,d in allHours:
    userSet.add(u)
    gameSet.add(g)
    playedSet.add((u, g))

lUserSet = list(userSet)
lGameSet = list(gameSet)

notPlayed = set()
for u,g,d in hoursValid:
    g = random.choice(lGameSet)
    while (u,g) in playedSet or (u,g) in notPlayed:
        g = random.choice(lGameSet)
    notPlayed.add((u,g))

playedValid = set()
for u,g,r in hoursValid:
    playedValid.add((u,g))

# %%
def Jaccard(s1, s2):
    numer = len(s1.intersection(s2))
    denom = len(s1.union(s2))
    if denom > 0:
        return numer / denom
    return 0

# %%
### Question 1

# %%
# From baseline code
def baseline_tune(coeff=2):
    gameCount = defaultdict(int)
    totalPlayed = 0

    for u,g,_ in hoursTrain:
        gameCount[g] += 1
        totalPlayed += 1

    mostPopular = [(gameCount[x], x) for x in gameCount]
    mostPopular.sort()
    mostPopular.reverse()

    return1 = set()
    count = 0
    for ic, i in mostPopular:
        count += ic
        return1.add(i)
        if count > totalPlayed/coeff: break
    return return1

# %%
# Evaluate baseline strategy
def baseline_eval(return1):
    correct = 0
    p0, p1 = 0, 0
    for (label, sample) in [(1, playedValid), (0, notPlayed)]:
        for (u,b) in sample:
            pred = 0
            if b in return1:
                pred = 1
            if pred == label:
                correct += 1
    return correct / (len(playedValid) + len(notPlayed))

# %%
# Out:
# {('u40167309', 'g75228197'),
#  ('u93459370', 'g79333823'),
#  ('u17061439', 'g25077590'),
#  ('u93778630', 'g53666531'),
#  ('u22749970', 'g42111697'),
#  ('u51238798', 'g26104453'),
#  ('u95010118', 'g83216730'),
#  ('u81196634', 'g96982884'),
#  ('u18251389', 'g49636917'),
#  ('u99378200', 'g25077590'),
#  ('u02506265', 'g77806076'),
#  ('u03233576', 'g25612121'),
#  ('u92338311', 'g90512019'),
#  ('u54615544', 'g42513315'),
#  ('u02633566', 'g01660600'),
#  ('u83279696', 'g67274965'),
#  ('u66660782', 'g16087475'),
#  ('u24965988', 'g92522857'),
#  ('u96104653', 'g98534046'),
#  ('u76594975', 'g21595192'),
#  ('u84256962', 'g24662129'),
#  ('u98637126', 'g68660659'),
#  ('u21687568', 'g45003838'),
#  ('u79736245', 'g92469827'),
#  ('u65891971', 'g60509936'),
#  ('u34253509', 'g30314000'),
#  ('u57078728', 'g74412462'),
#  ('u59520221', 'g85252310'),
#  ('u05548301', 'g82317851'),
#  ('u26109283', 'g92017077'),
#  ('u97630604', 'g03916495'),
#  ('u50132276', 'g34193208'),
#  ('u12208696', 'g67857266'),
#  ('u10763263', 'g10259243'),
#  ('u34600363', 'g93072028'),
#  ('u84027516', 'g24809309'),
#  ('u64256342', 'g64348065'),
#  ('u12428190', 'g83425645'),
#  ('u92892126', 'g18762273'),
#  ('u66627551', 'g29567022'),
#  ('u21516481', 'g74469956'),
#  ('u96016559', 'g80296997'),
#  ('u05315350', 'g31541380'),
#  ('u02618606', 'g06097413'),
#  ('u49255311', 'g15536656'),
#  ('u96429166', 'g10879560'),
#  ...}

# %%
correct / (len(playedValid) + len(notPlayed))
# Out:
# 6.684418441844184

# %%
bestCoef = 2
bestAcc = None
for coef in np.arange(1.4, 1.52, 0.0001):
    return1 = baseline_tune(coef)
    acc = baseline_eval(return1)
    if bestAcc == None or acc > bestAcc:
        bestCoef = coef
        bestAcc = acc

# %%
bestAcc, bestCoef
# Out:
# (0.7007200720072008, 1.4844999999999906)

# %%
answers['Q1'] = correct / (len(playedValid) + len(notPlayed))
answers['Q1']
# Out:
# 0.6807680768076808

# %%
assertFloat(answers['Q1'])

# %%
### Question 2

# %%
# Improved strategy
return1 = set()
count = 0
for ic, i in mostPopular:
    count += ic
    return1.add(i)
    if count > 1.5 * totalPlayed/2: break

# %%
# Evaluate baseline strategy

correct = 0
p0, p1 = 0,0
for (label, sample) in [(1, playedValid), (0, notPlayed)]:
    for (u,b) in sample:
        pred = 0
        if b in return1:
            pred = 1
        if pred == label:
            correct += 1

# %%
correct / (len(playedValid) + len(notPlayed))
# Out:
# 0.6914691469146915

# %%
answers['Q2'] = [1.5 * totalPlayed/2, correct / (len(playedValid) + len(notPlayed))]
answers['Q2']
# Out:
# [123750.0, 0.6914691469146915]

# %%
assertFloatList(answers['Q2'], 2)

# %%
### Question 3/4

# %%
# Slow implementation, could easily be improved following the code from Lecture 7

correct = 0
p0, p1 = 0,0
for (label, sample) in [(1, playedValid), (0, notPlayed)]:
    for (u,g) in sample:
        maxSim = 0
        users = set(hoursPerItem[g])
        for g2,_ in hoursPerItem[u]:
            sim = Jaccard(users, set(hoursPerItem[g2]))
            if sim > maxSim:
                maxSim = sim
        pred = 0
        if maxSim > 0.0025 or len(hoursPerItem[g]) > 79.8:
            pred = 1
            p1 += 1
        else:
            p0 += 1
        if pred == label:
            correct += 1

# %%
correct / (len(playedValid) + len(notPlayed))
# Out:
# 0.7011201120112012

# %%
answers['Q3'] = correct / (len(playedValid) + len(notPlayed))
answers['Q4'] = correct / (len(playedValid) + len(notPlayed))

# %%
assertFloat(answers['Q3'])
assertFloat(answers['Q4'])

# %%
hoursTrain[0]
# Out:
# ('u70666506',
#  'g49368897',
#  {'userID': 'u70666506',
#   'early_access': False,
#   'hours': 63.5,
#   'hours_transformed': 6.011227255423254,
#   'found_funny': 1,
#   'text': 'If you want to sit in queue for 10-20min and have 140 ping then this game is perfect for you :)',
#   'gameID': 'g49368897',
#   'user_id': '76561198030408772',
#   'date': '2017-05-20'})

# %% [markdown]
# ### Unique labels of the dictionary and their counts

# %%
labels = defaultdict(int)
funny_scores = defaultdict(int)
for u,g,d in allHours:
    for label in d:
        if label not in labels:
            labels[label] = 1
        else:
            labels[label] += 1
        if label == 'found_funny':
            score = d['found_funny']
            if score not in funny_scores:
                funny_scores[score] = 1
            else:
                funny_scores[score] += 1
labels
# Out:
# defaultdict(int,
#             {'userID': 174999,
#              'early_access': 174999,
#              'hours': 174999,
#              'hours_transformed': 174999,
#              'found_funny': 29938,
#              'text': 174999,
#              'gameID': 174999,
#              'user_id': 54841,
#              'date': 174999,
#              'compensation': 2870})

# %%
funny_scores
# Idea: only keep 1 as funny indicator, as numbers spread without much interpretation, though smaller numbers
# have higher frequency.
# Out:
# defaultdict(int,
#             {1: 16381,
#              6: 571,
#              4: 1338,
#              23: 45,
#              2: 5049,
#              3: 2267,
#              17: 76,
#              62: 8,
#              5: 865,
#              333: 1,
#              21: 40,
#              19: 56,
#              39: 15,
#              10: 212,
#              11: 166,
#              13: 128,
#              401: 1,
#              7: 405,
#              219: 1,
#              53: 12,
#              416: 2,
#              26: 36,
#              30: 14,
#              22: 54,
#              45: 16,
#              9: 265,
#              15: 87,
#              8: 342,
#              34: 15,
#              253: 2,
#              311: 1,
#              12: 158,
#              31: 24,
#              24: 29,
#              20: 36,
#              29: 29,
#              46: 14,
#              25: 33,
#              16: 65,
#              41: 15,
#              48: 15,
#              14: 111,
#              350: 1,
#              237: 3,
#              982: 1,
#              188: 3,
#              61: 13,
#              52: 8,
#              157: 2,
#              277: 2,
#              111: 1,
#              103: 6,
#              106: 6,
#              49: 11,
#              167: 2,
#              40: 18,
#              64: 9,
#              156: 3,
#              4013: 1,
#              59: 11,
#              32: 22,
#              435: 1,
#              60: 10,
#              65: 11,
#              27: 27,
#              50: 12,
#              199: 4,
#              18: 56,
#              47: 13,
#              57: 10,
#              28: 23,
#              78: 7,
#              70: 14,
#              44: 12,
#              38: 22,
#              93: 2,
#              152: 4,
#              1511: 1,
#              200: 2,
#              397: 1,
#              120: 1,
#              125: 5,
#              175: 3,
#              86: 2,
#              69: 5,
#              904: 1,
#              166: 2,
#              68: 2,
#              313: 1,
#              98: 2,
#              504: 1,
#              335: 1,
#              221: 2,
#              122: 2,
#              88: 3,
#              33: 21,
#              135: 1,
#              35: 20,
#              229: 1,
#              578: 1,
#              128: 2,
#              58: 7,
#              42: 10,
#              72: 8,
#              404: 1,
#              71: 10,
#              96: 4,
#              347: 1,
#              565: 2,
#              314: 1,
#              43: 15,
#              714: 1,
#              137: 2,
#              36: 21,
#              810: 1,
#              95: 2,
#              432: 2,
#              85: 5,
#              1184: 1,
#              66: 10,
#              94: 2,
#              104: 1,
#              141: 2,
#              204: 2,
#              56: 7,
#              198: 1,
#              633: 1,
#              118: 2,
#              820: 1,
#              147: 1,
#              102: 5,
#              1254: 1,
#              369: 1,
#              138: 3,
#              573: 1,
#              320: 1,
#              268: 1,
#              100: 3,
#              54: 9,
#              51: 7,
#              1964: 1,
#              771: 1,
#              1218: 1,
#              67: 9,
#              132: 2,
#              92: 3,
#              80: 5,
#              674: 1,
#              664: 1,
#              55: 10,
#              227: 2,
#              82: 3,
#              79: 2,
#              192: 1,
#              113: 2,
#              452: 1,
#              260: 1,
#              212: 1,
#              465: 1,
#              225: 3,
#              783: 1,
#              130: 2,
#              177: 1,
#              238: 1,
#              76: 8,
#              321: 1,
#              1006: 1,
#              391: 2,
#              269: 1,
#              533: 1,
#              101: 5,
#              83: 4,
#              37: 6,
#              795: 1,
#              87: 4,
#              292: 1,
#              1016: 1,
#              74: 3,
#              622: 1,
#              989: 1,
#              398: 2,
#              222: 1,
#              2515: 1,
#              123: 1,
#              344: 2,
#              146: 5,
#              97: 3,
#              518: 1,
#              112: 4,
#              841: 1,
#              288: 1,
#              143: 4,
#              136: 2,
#              881: 1,
#              145: 3,
#              75: 5,
#              576: 1,
#              77: 5,
#              291: 1,
#              632: 1,
#              265: 1,
#              109: 3,
#              271: 1,
#              774: 1,
#              105: 3,
#              267: 1,
#              952: 1,
#              151: 4,
#              172: 3,
#              73: 3,
#              821: 1,
#              163: 1,
#              90: 2,
#              403: 1,
#              926: 1,
#              213: 1,
#              140: 1,
#              337: 2,
#              354: 1,
#              497: 1,
#              226: 2,
#              537: 1,
#              159: 3,
#              925: 1,
#              247: 1,
#              121: 1,
#              84: 3,
#              286: 2,
#              327: 1,
#              317: 2,
#              99: 4,
#              266: 1,
#              402: 1,
#              158: 3,
#              131: 3,
#              107: 1,
#              312: 1,
#              302: 1,
#              606: 1,
#              440: 1,
#              170: 2,
#              154: 2,
#              572: 1,
#              1738: 1,
#              231: 1,
#              279: 1,
#              63: 5,
#              81: 2,
#              173: 2,
#              126: 1,
#              542: 1,
#              116: 2,
#              89: 3,
#              115: 3,
#              174: 1,
#              394: 1,
#              182: 1,
#              148: 2,
#              454: 1,
#              214: 1,
#              149: 4,
#              370: 1,
#              223: 1,
#              215: 2,
#              110: 2,
#              196: 3,
#              376: 1,
#              496: 1,
#              574: 2,
#              139: 1,
#              510: 1,
#              341: 1,
#              91: 3,
#              410: 1,
#              1045: 1,
#              218: 1,
#              958: 1,
#              332: 1,
#              515: 1,
#              201: 3,
#              117: 1,
#              2127: 1,
#              1206: 1,
#              283: 1,
#              799: 1,
#              323: 1,
#              207: 1,
#              251: 1,
#              220: 1,
#              127: 2,
#              541: 1,
#              108: 1,
#              628: 1,
#              589: 1,
#              246: 1,
#              743: 1,
#              228: 1,
#              232: 2,
#              254: 1,
#              467: 1,
#              264: 1,
#              195: 2,
#              161: 1,
#              315: 1,
#              206: 1,
#              191: 1,
#              155: 1,
#              1691: 1,
#              176: 1,
#              653: 1,
#              588: 1,
#              205: 1,
#              334: 1,
#              508: 1,
#              352: 1,
#              124: 3,
#              169: 1,
#              562: 1,
#              150: 1,
#              119: 2,
#              185: 1,
#              371: 1,
#              203: 1,
#              183: 1,
#              528: 2,
#              274: 1,
#              417: 1,
#              655: 1,
#              1809: 1,
#              296: 1,
#              356: 1,
#              190: 1,
#              129: 1,
#              245: 1,
#              114: 1,
#              385: 1,
#              1979: 1,
#              1497: 1,
#              160: 1,
#              553: 1,
#              243: 1,
#              1222: 1,
#              687: 1,
#              197: 1,
#              309: 1,
#              438: 1})

# %%
labels = defaultdict(int)
comp_text = defaultdict(int)
for u,g,d in allHours:
    for label in d:
        if label not in labels:
            labels[label] = 1
        else:
            labels[label] += 1
        if label == 'compensation':
            text = d['compensation']
            if text not in comp_text:
                comp_text[text] = 1
            else:
                comp_text[text] += 1
            # print(d['compensation'])
comp_text
# Out:
# defaultdict(int, {'Product received for free': 2870})

# %%
allHours[0]
# Out:
# ('u70666506',
#  'g49368897',
#  {'userID': 'u70666506',
#   'early_access': False,
#   'hours': 63.5,
#   'hours_transformed': 6.011227255423254,
#   'found_funny': 1,
#   'text': 'If you want to sit in queue for 10-20min and have 140 ping then this game is perfect for you :)',
#   'gameID': 'g49368897',
#   'user_id': '76561198030408772',
#   'date': '2017-05-20'})

# %%
year_analysis = defaultdict(list)
year_review = defaultdict(list)
year_count = defaultdict(int)
for u,g,d in allHours:
    year = d['date'][:4]
    year_analysis[year].append(d['hours'])
    year_count[year] += 1
    year_review[year].append(d)
year_analysis.keys()
# Out:
# dict_keys(['2017', '2014', '2015', '2016', '2011', '2013', '2012', '2018', '2010'])

# %%
# Average hours played in each year
for year in year_analysis:
    year_analysis[year] = sum(year_analysis[year]) / len(year_analysis[year])
year_analysis
# Out:
# defaultdict(list,
#             {'2017': 83.79954260953483,
#              '2014': 46.56876484994707,
#              '2015': 53.93078762119795,
#              '2016': 75.37695742780686,
#              '2011': 46.98958254983074,
#              '2013': 48.452502805836104,
#              '2012': 49.38314573459728,
#              '2018': 91.10154738878141,
#              '2010': 61.486481113320096})

# %%
year_count # count of user/game interactions in each year
# Out:
# defaultdict(int,
#             {'2017': 49848,
#              '2014': 27357,
#              '2015': 37645,
#              '2016': 43667,
#              '2011': 2659,
#              '2013': 8910,
#              '2012': 3376,
#              '2018': 1034,
#              '2010': 503})

# %%
plt.bar(x=year_count.keys(), height=year_count.values())
# Out:
# <BarContainer object of 9 artists>

# %%
year_review['2010'][3]
# Out:
# {'hours': 63.5,
#  'gameID': 'g66296428',
#  'hours_transformed': 6.011227255423254,
#  'early_access': False,
#  'date': '2010-11-27',
#  'text': 'Bioware follows up with the success of Mass Effect with this EPICLY WONDERFUL sequel!!! Mass Effect 2 improves upon the gameplay from the first game and further expands the narrative of the Mass Effect universe. No longer is exploration or managing equipment a tedious task. Instead the focus of Mass Effect 2 purely lies in the story that continously builds up to Cmdr. Shepard\'s "Final Mission." The gameplay still revolves around shoot \'n cover tactics, but the game\'s enhancements allow you to direct your squad making it more of a tactical third-person shooter than just a standard RPG. The story, gameplay, characters, graphics, locations, etc. make Mass Effect 2 THE GREATEST game I have ever played. Mass Effect 2 features several DLC packs that are available at Bioware\'s SocialNetwork and are well worth the investment for the full experience. Should be noted that Mass Effect 2 won the Golden Joystick\'s "Ultimate Game of the Year Award."',
#  'userID': 'u66682814'}

# %%
month_analysis = defaultdict(list)
month_count = defaultdict(int)
for u,g,d in allHours:
    month = d['date'][5:7]
    month_analysis[month].append(d['hours'])
    month_count[month] += 1
month_analysis.keys()
# Out:
# dict_keys(['05', '01', '03', '06', '07', '11', '12', '08', '10', '09', '02', '04'])

# %%
# Average hours played in each month
for month in month_analysis:
    month_analysis[month] = sum(month_analysis[month]) / len(month_analysis[month])
month_analysis
# Out:
# defaultdict(list,
#             {'05': 68.96121024734951,
#              '01': 62.947670836738254,
#              '03': 60.18789380530976,
#              '06': 60.89043926082992,
#              '07': 61.16173842908502,
#              '11': 94.48328233134076,
#              '12': 65.11318477251638,
#              '08': 58.82914078674914,
#              '10': 63.694643809523626,
#              '09': 58.738308823529074,
#              '02': 61.82269539078108,
#              '04': 65.48642556110924})

# %% [markdown]
# Seems November is a hot month to play games! Many reviews, much higher average play time as well...

# %%
month_count
# Out:
# defaultdict(int,
#             {'05': 11320,
#              '01': 15907,
#              '03': 11300,
#              '06': 16505,
#              '07': 16118,
#              '11': 21241,
#              '12': 21540,
#              '08': 13524,
#              '10': 13125,
#              '09': 12240,
#              '02': 11976,
#              '04': 10203})

# %%
plt.bar(x=month_count.keys(), height=month_count.values())
# Out:
# <BarContainer object of 12 artists>

# %%
day_analysis = defaultdict(list)
day_count = defaultdict(int)
for u,g,d in allHours:
    day = d['date'][8:10]
    day_analysis[day].append(d['hours'])
    day_count[day] += 1
day_analysis.keys()
# Out:
# dict_keys(['20', '27', '06', '13', '17', '14', '19', '15', '03', '01', '23', '07', '18', '24', '26', '31', '12', '11', '30', '09', '04', '22', '10', '25', '28', '02', '05', '08', '16', '21', '29'])

# %%
# Average hours played in each day
for day in day_analysis:
    day_analysis[day] = sum(day_analysis[day]) / len(day_analysis[day])

# %%
plt.bar(x=day_count.keys(), height=day_count.values())
# Out:
# <BarContainer object of 31 artists>

# %% [markdown]
# ### Potential Idea: do a sentiment analysis on text data. Label sentiment as positive if hours played exceeds certain threshold. Maybe label as positive if funny is a key in the dictionary?

# %% [markdown]
# ## Try Bayesian Personalized Ranking with TF

# %%
items = list(gameSet)
items[:3]
# Out:
# ['g78817804', 'g32174391', 'g92018877']

# %%
class BPRbatch(tf.keras.Model):
    def __init__(self, K, lamb):
        super(BPRbatch, self).__init__()
        # Initialize variables
        self.betaI = tf.Variable(tf.random.normal([len(gameSet)], stddev=0.001))
        self.gammaU = tf.Variable(tf.random.normal([len(userSet), K], stddev=0.001))
        self.gammaI = tf.Variable(tf.random.normal([len(gameSet), K], stddev=0.001))
        # Regularization coefficient
        self.lamb = lamb
    
    # Prediction for a single instance
    def predict(self, u, i):
        p = self.betaI[i] + tf.tensordot(self.gammaU[u], self.gammaI[i], 1)
        return p
    
    # Regularizer
    def reg(self):
        return self.lamb * (tf.nn.l2_loss(self.betaI) +\
                            tf.nn.l2_loss(self.gammaU) +\
                            tf.nn.l2_loss(self.gammaI))
    
    def score(self, sampleU, sampleI):
        u = tf.convert_to_tensor(sampleU, dtype=tf.int32)
        i = tf.convert_to_tensor(sampleI, dtype=tf.int32)
        beta_i = tf.nn.embedding_lookup(self.betaI, i)
        gamma_u = tf.nn.embedding_lookup(self.gammaU, u)
        gamma_i = tf.nn.embedding_lookup(self.gammaI, i)
        x_ui = beta_i + tf.reduce_sum(tf.multiply(gamma_u, gamma_i), 1)
        return x_ui
    
    def call(self, sampleU, sampleI, sampleJ):
        x_ui = self.score(sampleU, sampleI)
        x_uj = self.score(sampleU, sampleJ)
        return -tf.reduce_mean(tf.math.log(tf.math.sigmoid(x_ui - x_uj)))

# %%
optimizer = tf.keras.optimizers.Adam(0.1)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %%
modelBPR = BPRbatch(5, 0.00001)

# %%
def trainingStepBPR(model, interactions):
    Nsamples = 50000
    with tf.GradientTape() as tape:
        sampleU, sampleI, sampleJ = [],[],[]
        for _ in range(Nsamples):
            u,i,_ = random.choice(interactions) # positive sample
            j = random.choice(items) # negative sample
            while j in itemsPerUser[u]:
                j = random.choice(items)
            sampleU.append(userIDs[u])
            sampleI.append(itemIDs[i])
            sampleJ.append(itemIDs[j])
        
        loss = model(sampleU, sampleI, sampleJ)
        loss += model.reg()
    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients((grad, var) for 
                              (grad, var) in zip(gradients, model.trainable_variables)
                              if grad is not None)
    return loss.numpy()

# %%
# Run 100 batches of gradient descent
for i in range(150):
    obj = trainingStepBPR(modelBPR, interactions)
    if (i % 10 == 9): print("Iteration " + str(i+1) + ", objective = " + str(obj))
# Out:
# Iteration 10, objective = 0.44286746
# Iteration 20, objective = 0.43869245
# Iteration 30, objective = 0.44299737
# Iteration 40, objective = 0.438866
# Iteration 50, objective = 0.44065997
# Iteration 60, objective = 0.44157162
# Iteration 70, objective = 0.4389225
# Iteration 80, objective = 0.44031608
# Iteration 90, objective = 0.44281122
# Iteration 100, objective = 0.44434315
# Iteration 110, objective = 0.443828
# Iteration 120, objective = 0.44024548
# Iteration 130, objective = 0.43974674
# Iteration 140, objective = 0.44286096
# Iteration 150, objective = 0.43853307

# %%
interactionsTrain = interactions[:165000]
interactionsTest = interactions[165000:]

# %%
u,i,_ = interactionsTest[0]

# %%
# In this case just a score, rather than a prediction of a rating
modelBPR.predict(userIDs[u], itemIDs[i]).numpy()
# Out:
# 0.42950755

# %%
Scores = []
negScore = []
for u,i,_ in interactionsTrain:
    score = modelBPR.predict(userIDs[u], itemIDs[i]).numpy()
    Scores.append(score)
    if score < 0:
        negScore.append(score)

# %%
negScore.sort()
negScore.reverse()
negScore[int(len(negScore)*0.5)]
# Out:
# -0.34477544

# %%
interactionsTestPerUser = defaultdict(set)
itemSet = set()
for u,i,_ in interactionsTest:
    interactionsTestPerUser[u].add(i)
    itemSet.add(i)

# %%
def AUCu(u, N): # N samples per user
    win = 0
    if N > len(interactionsTestPerUser[u]):
        N = len(interactionsTestPerUser[u])
    positive = random.sample(interactionsTestPerUser[u],N)
    negative = random.sample(gameSet.difference(interactionsTestPerUser[u]),N)
    for i,j in zip(positive,negative):
        si = modelBPR.predict(userIDs[u], itemIDs[i]).numpy()
        sj = modelBPR.predict(userIDs[u], itemIDs[j]).numpy()
        if si > sj:
            win += 1
    return win/N

# %%
def AUC():
    av = []
    for u in interactionsTestPerUser:
        av.append(AUCu(u, 10))
    return sum(av) / len(av)

# %%
AUC()
# Out:
# /var/folders/8f/_6h5xprs32dfmm3jfs0g7k880000gn/T/ipykernel_2291/3135776419.py:5: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   positive = random.sample(interactionsTestPerUser[u],N)
# /var/folders/8f/_6h5xprs32dfmm3jfs0g7k880000gn/T/ipykernel_2291/3135776419.py:6: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   negative = random.sample(gameSet.difference(interactionsTestPerUser[u]),N)
# 0.827615883009376

# %%
correct = 0
scores = []
for u,g,_ in hoursTrain:
    score = modelBPR.predict(userIDs[u], itemIDs[g])
    scores.append(score)
    pred = 0
    if score > 0.5:
        pred = 1
    if pred == 1:
        correct += 1

# %%
correct / len(hoursTrain)
# Out:
# 0.8101515151515152

# %%
predictions = open("predictions_Played.csv", 'w')
for l in open("pairs_Played.csv"):
    if l.startswith("userID"):
        predictions.write(l)
        continue
    u,g = l.strip().split(',')
    if u in userIDs and g in itemIDs:
        score = modelBPR.predict(userIDs[u], itemIDs[g]).numpy()
    else:
        score = -1
    # maxSim = 0
    # users = set(hoursPerItem[g])
    # for g2,_ in hoursPerUser[u]:
    #     sim = Jaccard(users, hoursPerItem[g2])
    #     if sim > maxSim:
    #         maxSim = sim
    pred = 0
    if score > 0.5:
    # or len(hoursPerItem[g]) > 79.8:
        pred = 1
    _ = predictions.write(u + ',' + g + ',' + str(pred) + '\n')

predictions.close()

# %% [markdown]
# ## Sentiment analysis of review text

# %%
predictions = open("predictions_Played.csv", 'w')
for l in open("pairs_Played.csv"):
    if l.startswith("userID"):
        predictions.write(l)
        continue
    u,g = l.strip().split(',')
    maxSim = 0
    users = set(hoursPerItem[g])
    for g2,_ in hoursPerUser[u]:
        sim = Jaccard(users, hoursPerItem[g2])
        if sim > maxSim:
            maxSim = sim
    pred = 0
    if maxSim > 0.025 or len(hoursPerItem[g]) > 79.8:
        pred = 1
    _ = predictions.write(u + ',' + g + ',' + str(pred) + '\n')

predictions.close()

# %%
answers['Q5'] = "I confirm that I have uploaded an assignment submission to gradescope"

# %%
##################################################
# Hours played prediction                        #
##################################################

# %%
trainHours = [r[2]['hours_transformed'] for r in hoursTrain]
globalAverage = sum(trainHours) * 1.0 / len(hoursTrain)

# %%
validMSE = 0
for u,g,d in hoursValid:
    r = d['hours_transformed']
    se = (r- globalAverage)**2
    validMSE += se

validMSE /= len(hoursValid)

print("Validation MSE (average only) = " + str(validMSE))
# Out:
# Validation MSE (average only) = 5.316020858088501

# %%
### Question 6

# %%
betaU = {}
betaI = {}
for u in hoursPerUser:
    betaU[u] = 0

for g in hoursPerItem:
    betaI[g] = 0

# %%
alpha = globalAverage # Could initialize anywhere, this is a guess

# %%
def iterate(lamb):
    newAlpha = 0
    for u,g,d in hoursTrain:
        r = d['hours_transformed']
        newAlpha += r - (betaU[u] + betaI[g])
    alpha = newAlpha / len(hoursTrain)
    for u in hoursPerUser:
        newBetaU = 0
        for g,r in hoursPerUser[u]:
            newBetaU += r - (alpha + betaI[g])
        betaU[u] = newBetaU / (lamb + len(hoursPerUser[u]))
    for g in hoursPerItem:
        newBetaI = 0
        for u,r in hoursPerItem[g]:
            newBetaI += r - (alpha + betaU[u])
        betaI[g] = newBetaI / (lamb + len(hoursPerItem[g]))
    mse = 0
    for u,g,d in hoursTrain:
        r = d['hours_transformed']
        prediction = alpha + betaU[u] + betaI[g]
        mse += (r - prediction)**2
    regularizer = 0
    for u in betaU:
        regularizer += betaU[u]**2
    for g in betaI:
        regularizer += betaI[g]**2
    mse /= len(hoursTrain)
    return mse, mse + lamb*regularizer

# %%
mse, objective = iterate(1)
newMSE, newObjective = iterate(1)
iterations = 2

# %%
while iterations < 10 or objective - newObjective > 0.01:
    mse, objective = newMSE, newObjective
    newMSE, newObjective = iterate(1)
    iterations += 1
    print("Objective after "
        + str(iterations) + " iterations = " + str(newObjective))
    print("MSE after "
        + str(iterations) + " iterations = " + str(newMSE))
# Out:
# Objective after 3 iterations = 6949.371887214059
# MSE after 3 iterations = 2.7564084708391015
# Objective after 4 iterations = 6969.457095076773
# MSE after 4 iterations = 2.7556133685143775
# Objective after 5 iterations = 6959.860929545761
# MSE after 5 iterations = 2.755497315461903
# Objective after 6 iterations = 6942.021172986504
# MSE after 6 iterations = 2.755468887940564
# Objective after 7 iterations = 6922.315789845392
# MSE after 7 iterations = 2.7554572083332287
# Objective after 8 iterations = 6902.457958240189
# MSE after 8 iterations = 2.755449566226792
# Objective after 9 iterations = 6882.895284113965
# MSE after 9 iterations = 2.755443039374811
# Objective after 10 iterations = 6863.740383717009
# MSE after 10 iterations = 2.755436886252961
# Objective after 11 iterations = 6845.017428754594
# MSE after 11 iterations = 2.7554309119053677
# Objective after 12 iterations = 6826.727196367468
# MSE after 12 iterations = 2.755425063819739
# Objective after 13 iterations = 6808.864265552004
# MSE after 13 iterations = 2.7554193270656064
# Objective after 14 iterations = 6791.421577769298
# MSE after 14 iterations = 2.755413696660634
# Objective after 15 iterations = 6774.39165268468
# MSE after 15 iterations = 2.755408170250991
# Objective after 16 iterations = 6757.76691648657
# MSE after 16 iterations = 2.7554027461690667
# Objective after 17 iterations = 6741.539794212059
# MSE after 17 iterations = 2.7553974229194367
# Objective after 18 iterations = 6725.702739038241
# MSE after 18 iterations = 2.7553921990438517
# Objective after 19 iterations = 6710.248244515378
# MSE after 19 iterations = 2.75538707308708
# Objective after 20 iterations = 6695.168851977195
# MSE after 20 iterations = 2.755382043589917
# Objective after 21 iterations = 6680.457156391499
# MSE after 21 iterations = 2.7553771090881485
# Objective after 22 iterations = 6666.105811527667
# MSE after 22 iterations = 2.755372268114555
# Objective after 23 iterations = 6652.107534682644
# MSE after 23 iterations = 2.7553675192003992
# Objective after 24 iterations = 6638.455111038441
# MSE after 24 iterations = 2.7553628608772014
# Objective after 25 iterations = 6625.141397679209
# MSE after 25 iterations = 2.7553582916784216
# Objective after 26 iterations = 6612.159327284069
# MSE after 26 iterations = 2.7553538101410773
# Objective after 27 iterations = 6599.5019115099985
# MSE after 27 iterations = 2.7553494148070583
# Objective after 28 iterations = 6587.162244076331
# Objective after 65 iterations = 6299.475938318262
# MSE after 65 iterations = 2.755233107462837
# Objective after 66 iterations = 6295.032046537145
# MSE after 66 iterations = 2.7552310777972098
# Objective after 67 iterations = 6290.710745530818
# MSE after 67 iterations = 2.7552290878161836
# Objective after 68 iterations = 6286.508833738314
# MSE after 68 iterations = 2.7552271367059755
# Objective after 69 iterations = 6282.4231850435135
# MSE after 69 iterations = 2.75522522366877
# Objective after 70 iterations = 6278.450747421737
# MSE after 70 iterations = 2.755223347922446
# Objective after 71 iterations = 6274.588541585462
# MSE after 71 iterations = 2.7552215087003273
# Objective after 72 iterations = 6270.833659632355
# MSE after 72 iterations = 2.755219705250847
# Objective after 73 iterations = 6267.183263696241
# MSE after 73 iterations = 2.7552179368375334
# Objective after 74 iterations = 6263.634584603498
# MSE after 74 iterations = 2.7552162027387688
# Objective after 75 iterations = 6260.1849205351455
# MSE after 75 iterations = 2.7552145022472567
# Objective after 76 iterations = 6256.831635697221
# MSE after 76 iterations = 2.7552128346702656
# Objective after 77 iterations = 6253.572158999708
# MSE after 77 iterations = 2.755211199328962
# Objective after 78 iterations = 6250.403982745616
# MSE after 78 iterations = 2.75520959555841
# Objective after 79 iterations = 6247.32466133103
# MSE after 79 iterations = 2.7552080227074804
# Objective after 80 iterations = 6244.331809957146
# MSE after 80 iterations = 2.755206480138175
# Objective after 81 iterations = 6241.423103355262
# MSE after 81 iterations = 2.7552049672259034
# Objective after 82 iterations = 6238.596274525234
# MSE after 82 iterations = 2.755203483358797
# Objective after 83 iterations = 6235.84911348841
# MSE after 83 iterations = 2.755202027937951
# Objective after 84 iterations = 6233.179466055264
# MSE after 84 iterations = 2.755200600376634
# Objective after 85 iterations = 6230.585232608926
# MSE after 85 iterations = 2.7551992001005976
# Objective after 86 iterations = 6228.064366904375
# MSE after 86 iterations = 2.7551978265475725
# Objective after 87 iterations = 6225.614874884312
# MSE after 87 iterations = 2.755196479166995
# Objective after 88 iterations = 6223.234813511913
# MSE after 88 iterations = 2.7551951574201743
# Objective after 89 iterations = 6220.922289620707
# MSE after 89 iterations = 2.7551938607794306
# Objective after 90 iterations = 6218.675458781934
# MSE after 90 iterations = 2.755192588728506
# Objective after 91 iterations = 6216.492524189728
# MSE after 91 iterations = 2.7551913407618898
# Objective after 92 iterations = 6214.371735564331
# MSE after 92 iterations = 2.7551901163849286
# Objective after 93 iterations = 6212.311388073214
# MSE after 93 iterations = 2.755188915113347
# Objective after 94 iterations = 6210.309821270574
# MSE after 94 iterations = 2.75518773647329
# Objective after 95 iterations = 6208.365418055358
# MSE after 95 iterations = 2.755186580001051
# Objective after 96 iterations = 6206.476603647284
# MSE after 96 iterations = 2.755185445242647
# Objective after 97 iterations = 6204.641844581666
# MSE after 97 iterations = 2.7551843317539753
# Objective after 98 iterations = 6202.8596477225865
# MSE after 98 iterations = 2.7551832391002273
# Objective after 99 iterations = 6201.128559294385
# MSE after 99 iterations = 2.755182166856233
# Objective after 100 iterations = 6199.447163931706
# MSE after 100 iterations = 2.7551811146055383
# Objective after 101 iterations = 6197.81408374775
# MSE after 101 iterations = 2.7551800819408334
# Objective after 102 iterations = 6196.227977420825
# MSE after 102 iterations = 2.755179068463574
# Objective after 103 iterations = 6194.687539298904
# MSE after 103 iterations = 2.7551780737837954
# Objective after 104 iterations = 6193.191498522382
# MSE after 104 iterations = 2.755177097519774
# Objective after 105 iterations = 6191.738618164641
# MSE after 105 iterations = 2.755176139298066
# Objective after 106 iterations = 6190.327694390115
# MSE after 106 iterations = 2.7551751987533626
# Objective after 107 iterations = 6188.957555630191
# MSE after 107 iterations = 2.7551742755280344
# Objective after 108 iterations = 6187.627061776377
# MSE after 108 iterations = 2.7551733692723053
# Objective after 109 iterations = 6186.335103390711
# MSE after 109 iterations = 2.7551724796437123
# Objective after 110 iterations = 6185.080600932944
# MSE after 110 iterations = 2.7551716063075706
# Objective after 111 iterations = 6183.862504004809
# MSE after 111 iterations = 2.7551707489359747
# Objective after 112 iterations = 6182.67979061059
# MSE after 112 iterations = 2.7551699072082574
# Objective after 113 iterations = 6181.531466434303
# MSE after 113 iterations = 2.7551690808106186
# Objective after 114 iterations = 6180.416564132737
# MSE after 114 iterations = 2.755168269436167
# Objective after 115 iterations = 6179.3341426444995
# MSE after 115 iterations = 2.7551674727844544
# Objective after 116 iterations = 6178.283286514782
# MSE after 116 iterations = 2.7551666905614747
# Objective after 117 iterations = 6177.263105235339
# MSE after 117 iterations = 2.75516592247958
# Objective after 118 iterations = 6176.272732599857
# MSE after 118 iterations = 2.755165168257374
# Objective after 119 iterations = 6175.311326074101
# MSE after 119 iterations = 2.7551644276195737
# Objective after 120 iterations = 6174.378066180695
# MSE after 120 iterations = 2.7551637002964786
# Objective after 121 iterations = 6173.472155898459
# MSE after 121 iterations = 2.755162986024544
# Objective after 122 iterations = 6172.592820075695
# MSE after 122 iterations = 2.7551622845456474
# Objective after 123 iterations = 6171.739304857854
# MSE after 123 iterations = 2.7551615956073663
# Objective after 124 iterations = 6170.91087712796
# MSE after 124 iterations = 2.7551609189625683
# Objective after 125 iterations = 6170.106823961554
# MSE after 125 iterations = 2.7551602543693603
# Objective after 126 iterations = 6169.326452093814
# MSE after 126 iterations = 2.755159601591283
# Objective after 127 iterations = 6168.569087400271
# MSE after 127 iterations = 2.755158960396538
# Objective after 128 iterations = 6167.834074389834
# MSE after 128 iterations = 2.7551583305586838
# Objective after 129 iterations = 6167.120775710086
# MSE after 129 iterations = 2.7551577118558574
# Objective after 130 iterations = 6166.428571665079
# MSE after 130 iterations = 2.75515710407091
# Objective after 131 iterations = 6165.756859744878
# MSE after 131 iterations = 2.7551565069914274
# Objective after 132 iterations = 6165.105054166641
# MSE after 132 iterations = 2.755155920409551
# Objective after 133 iterations = 6164.472585427336
# MSE after 133 iterations = 2.755155344121745
# Objective after 134 iterations = 6163.85889986734
# MSE after 134 iterations = 2.7551547779286127
# Objective after 135 iterations = 6163.263459245402
# MSE after 135 iterations = 2.755154221635478
# Objective after 136 iterations = 6162.685740323846
# MSE after 136 iterations = 2.755153675051289
# Objective after 137 iterations = 6162.125234464551
# MSE after 137 iterations = 2.755153137989342
# Objective after 175 iterations = 6149.745904346236
# MSE after 175 iterations = 2.7551382812048413
# Objective after 176 iterations = 6149.578955638956
# MSE after 176 iterations = 2.7551380042136064
# Objective after 177 iterations = 6149.417273414367
# MSE after 177 iterations = 2.755137731737706
# Objective after 178 iterations = 6149.260701376163
# MSE after 178 iterations = 2.755137463697023
# Objective after 179 iterations = 6149.109087725582
# MSE after 179 iterations = 2.755137200013146
# Objective after 180 iterations = 6148.962285034727
# MSE after 180 iterations = 2.7551369406089683
# Objective after 181 iterations = 6148.820150123325
# MSE after 181 iterations = 2.7551366854091226
# Objective after 182 iterations = 6148.682543938973
# MSE after 182 iterations = 2.755136434339607
# Objective after 183 iterations = 6148.549331440571
# MSE after 183 iterations = 2.7551361873277687
# Objective after 184 iterations = 6148.420381485073
# MSE after 184 iterations = 2.7551359443026673
# Objective after 185 iterations = 6148.295566717278
# MSE after 185 iterations = 2.7551357051942986
# Objective after 186 iterations = 6148.17476346265
# MSE after 186 iterations = 2.755135469934491
# Objective after 187 iterations = 6148.0578516234245
# MSE after 187 iterations = 2.7551352384560515
# Objective after 188 iterations = 6147.944714577039
# MSE after 188 iterations = 2.755135010693233
# Objective after 189 iterations = 6147.8352390778955
# MSE after 189 iterations = 2.755134786581382
# Objective after 190 iterations = 6147.729315161444
# MSE after 190 iterations = 2.7551345660573707
# Objective after 191 iterations = 6147.626836051441
# MSE after 191 iterations = 2.7551343490590203
# Objective after 192 iterations = 6147.527698069054
# MSE after 192 iterations = 2.7551341355254957
# Objective after 193 iterations = 6147.431800545274
# MSE after 193 iterations = 2.755133925397097
# Objective after 194 iterations = 6147.339045735235
# MSE after 194 iterations = 2.7551337186151925
# Objective after 195 iterations = 6147.249338735056
# MSE after 195 iterations = 2.7551335151223024
# Objective after 196 iterations = 6147.162587401169
# MSE after 196 iterations = 2.7551333148621233
# Objective after 197 iterations = 6147.078702271701
# MSE after 197 iterations = 2.7551331177791973
# Objective after 198 iterations = 6146.997596490155
# MSE after 198 iterations = 2.755132923819456
# Objective after 199 iterations = 6146.919185731006
# MSE after 199 iterations = 2.7551327329294737
# Objective after 200 iterations = 6146.843388127882
# MSE after 200 iterations = 2.7551325450570796
# Objective after 201 iterations = 6146.770124203228
# MSE after 201 iterations = 2.755132360150981
# Objective after 202 iterations = 6146.699316800109
# MSE after 202 iterations = 2.75513217816085
# Objective after 203 iterations = 6146.630891016119
# MSE after 203 iterations = 2.755131999037415
# Objective after 204 iterations = 6146.564774138893
# MSE after 204 iterations = 2.7551318227320816
# Objective after 205 iterations = 6146.500895583485
# MSE after 205 iterations = 2.7551316491974474
# Objective after 206 iterations = 6146.43918683171
# MSE after 206 iterations = 2.7551314783867764
# Objective after 207 iterations = 6146.37958137282
# MSE after 207 iterations = 2.755131310254209
# Objective after 208 iterations = 6146.322014646071
# MSE after 208 iterations = 2.7551311447549076
# Objective after 209 iterations = 6146.266423985103
# MSE after 209 iterations = 2.7551309818447054
# Objective after 210 iterations = 6146.212748563488
# MSE after 210 iterations = 2.7551308214802326
# Objective after 211 iterations = 6146.160929341902
# Objective after 248 iterations = 6145.1395838274475
# MSE after 248 iterations = 2.7551262559768395
# Objective after 249 iterations = 6145.1279442322775
# MSE after 249 iterations = 2.755126168187249
# Objective after 250 iterations = 6145.116826614673
# MSE after 250 iterations = 2.7551260817213024
# Objective after 251 iterations = 6145.106213445617
# MSE after 251 iterations = 2.7551259965580805
# Objective after 252 iterations = 6145.096087731401
# MSE after 252 iterations = 2.7551259126770753
# Objective after 253 iterations = 6145.086432997997
# MSE after 253 iterations = 2.7551258300581063

# %%
validMSE = 0
for u,g,d in hoursValid:
    r = d['hours_transformed']
    bu = 0
    bi = 0
    if u in betaU:
        bu = betaU[u]
    if g in betaI:
        bi = betaI[g]
    prediction = alpha + bu + bi
    validMSE += (r - prediction)**2

validMSE /= len(hoursValid)
print("Validation MSE = " + str(validMSE))
# Out:
# Validation MSE = 3.3620999448808417

# %%
answers['Q6'] = validMSE

# %%
assertFloat(answers['Q6'])

# %%
### Question 7

# %%
betaUs = [(betaU[u], u) for u in betaU]
betaIs = [(betaI[i], i) for i in betaI]
betaUs.sort()
betaIs.sort()

print("Maximum betaU = " + str(betaUs[-1][1]) + ' (' + str(betaUs[-1][0]) + ')')
print("Maximum betaI = " + str(betaIs[-1][1]) + ' (' + str(betaIs[-1][0]) + ')')
print("Minimum betaU = " + str(betaUs[0][1]) + ' (' + str(betaUs[0][0]) + ')')
print("Minimum betaI = " + str(betaIs[0][1]) + ' (' + str(betaIs[0][0]) + ')')
# Out:
# Maximum betaU = u60898505 (5.828316004463382)
# Maximum betaI = g17604638 (5.496003738829189)
# Minimum betaU = u13037838 (-3.005788036433242)
# Minimum betaI = g84397720 (-2.80929889234237)

# %%
answers['Q7'] = [betaUs[-1][0], betaUs[0][0], betaIs[-1][0], betaIs[0][0]]
answers['Q7']
# Out:
# [5.828316004463382, -3.005788036433242, 5.496003738829189, -2.80929889234237]

# %%
assertFloatList(answers['Q7'], 4)

# %%
### Question 8

# %%
# Better lambda...

iterations = 1
while iterations < 10 or objective - newObjective > 0.01:
    mse, objective = newMSE, newObjective
    newMSE, newObjective = iterate(5)
    iterations += 1
    print("Objective after "
        + str(iterations) + " iterations = " + str(newObjective))
    print("MSE after "
        + str(iterations) + " iterations = " + str(newMSE))
# Out:
# Objective after 2 iterations = 23723.43363128721
# MSE after 2 iterations = 2.7788622928906777
# Objective after 3 iterations = 23510.614580035824
# MSE after 3 iterations = 2.7795090635183897
# Objective after 4 iterations = 23487.1358148199
# MSE after 4 iterations = 2.7796328706435727
# Objective after 5 iterations = 23482.629189140025
# MSE after 5 iterations = 2.7796578901263955
# Objective after 6 iterations = 23481.098216879294
# MSE after 6 iterations = 2.7796656576503596
# Objective after 7 iterations = 23480.151680333896
# MSE after 7 iterations = 2.7796700570883783
# Objective after 8 iterations = 23479.35821087336
# MSE after 8 iterations = 2.7796736661690313
# Objective after 9 iterations = 23478.632440801233
# MSE after 9 iterations = 2.77967699001243
# Objective after 10 iterations = 23477.955585702766
# MSE after 10 iterations = 2.7796801315658564
# Objective after 11 iterations = 23477.322147240444
# MSE after 11 iterations = 2.779683113761583
# Objective after 12 iterations = 23476.72930039359
# MSE after 12 iterations = 2.7796859438945614
# Objective after 13 iterations = 23476.174756791293
# MSE after 13 iterations = 2.779688626633493
# Objective after 14 iterations = 23475.65635033589
# MSE after 14 iterations = 2.7796911665654793
# Objective after 15 iterations = 23475.171972542063
# MSE after 15 iterations = 2.779693568597693
# Objective after 16 iterations = 23474.719575037285
# MSE after 16 iterations = 2.779695837934175
# Objective after 17 iterations = 23474.297181403323
# MSE after 17 iterations = 2.7796979799843635
# Objective after 18 iterations = 23473.902897212378
# MSE after 18 iterations = 2.779700000271903
# Objective after 19 iterations = 23473.534916737164
# MSE after 19 iterations = 2.7797019043591034
# Objective after 20 iterations = 23473.191526684175
# MSE after 20 iterations = 2.7797036977851595
# Objective after 21 iterations = 23472.871107569226
# MSE after 21 iterations = 2.779705386017632
# Objective after 22 iterations = 23472.57213329899
# MSE after 22 iterations = 2.7797069744140765
# Objective after 23 iterations = 23472.293169423934
# MSE after 23 iterations = 2.77970846819307
# Objective after 24 iterations = 23472.03287043545
# MSE after 24 iterations = 2.7797098724124845
# Objective after 25 iterations = 23471.789976398224
# MSE after 25 iterations = 2.7797111919533415
# Objective after 26 iterations = 23471.563309145804
# MSE after 26 iterations = 2.7797124315097186
# Objective after 27 iterations = 23471.351768214296
# MSE after 27 iterations = 2.779713595580953
# Objective after 28 iterations = 23471.154326650354
# MSE after 28 iterations = 2.7797146884692503
# Objective after 29 iterations = 23470.970026791692
# MSE after 29 iterations = 2.779715714277734
# Objective after 30 iterations = 23470.797976097685
# MSE after 30 iterations = 2.779716676912659
# Objective after 31 iterations = 23470.637343081635
# MSE after 31 iterations = 2.779717580085816
# Objective after 32 iterations = 23470.487353384488
# MSE after 32 iterations = 2.7797184273186106
# Objective after 33 iterations = 23470.34728601573
# MSE after 33 iterations = 2.7797192219475826
# Objective after 34 iterations = 23470.216469775743
# MSE after 34 iterations = 2.7797199671300064
# Objective after 35 iterations = 23470.094279870144
# MSE after 35 iterations = 2.779720665850625
# Objective after 36 iterations = 23469.98013471799
# MSE after 36 iterations = 2.7797213209278198
# Objective after 37 iterations = 23469.87349295398
# MSE after 37 iterations = 2.7797219350212594
# Objective after 38 iterations = 23469.77385061885
# MSE after 38 iterations = 2.779722510638567
# Objective after 39 iterations = 23469.680738535048
# MSE after 39 iterations = 2.7797230501425823
# Objective after 40 iterations = 23469.593719856293
# MSE after 40 iterations = 2.779723555758116
# Objective after 41 iterations = 23469.512387785846
# MSE after 41 iterations = 2.7797240295793073
# Objective after 42 iterations = 23469.43636345333
# MSE after 42 iterations = 2.7797244735758158
# Objective after 43 iterations = 23469.365293940005
# MSE after 43 iterations = 2.7797248896000415
# Objective after 44 iterations = 23469.298850446263
# MSE after 44 iterations = 2.779725279392732
# Objective after 45 iterations = 23469.23672658709
# MSE after 45 iterations = 2.7797256445897873
# Objective after 46 iterations = 23469.17863681407
# MSE after 46 iterations = 2.7797259867276307
# Objective after 47 iterations = 23469.12431494844
# MSE after 47 iterations = 2.7797263072489824
# Objective after 48 iterations = 23469.07351282119
# MSE after 48 iterations = 2.779726607508366
# Objective after 49 iterations = 23469.025999012545
# MSE after 49 iterations = 2.7797268887768616
# Objective after 50 iterations = 23468.981557681996
# MSE after 50 iterations = 2.7797271522476463
# Objective after 51 iterations = 23468.939987483187
# MSE after 51 iterations = 2.779727399039574
# Objective after 52 iterations = 23468.901100557618
# MSE after 52 iterations = 2.779727630202732
# Objective after 53 iterations = 23468.86472160132
# MSE after 53 iterations = 2.7797278467215443
# Objective after 54 iterations = 23468.830686997946
# MSE after 54 iterations = 2.7797280495194694
# Objective after 55 iterations = 23468.79884401548
# MSE after 55 iterations = 2.7797282394621736
# Objective after 56 iterations = 23468.769050058992
# MSE after 56 iterations = 2.7797284173613015
# Objective after 57 iterations = 23468.74117197827
# MSE after 57 iterations = 2.779728583977786
# Objective after 58 iterations = 23468.71508542377
# MSE after 58 iterations = 2.779728740024815
# Objective after 59 iterations = 23468.69067424916
# MSE after 59 iterations = 2.7797288861707643
# Objective after 60 iterations = 23468.667829955193
# MSE after 60 iterations = 2.7797290230421523
# Objective after 61 iterations = 23468.64645117259
# MSE after 61 iterations = 2.7797291512261295
# Objective after 62 iterations = 23468.62644318348
# MSE after 62 iterations = 2.779729271272638
# Objective after 63 iterations = 23468.60771747289
# MSE after 63 iterations = 2.7797293836973656
# Objective after 64 iterations = 23468.59019131402
# MSE after 64 iterations = 2.779729488983128
# Objective after 65 iterations = 23468.573787381534
# MSE after 65 iterations = 2.7797295875824415
# Objective after 66 iterations = 23468.55843339149
# MSE after 66 iterations = 2.7797296799194138
# Objective after 67 iterations = 23468.544061765915
# MSE after 67 iterations = 2.7797297663908984
# Objective after 68 iterations = 23468.530609320846
# MSE after 68 iterations = 2.7797298473691745
# Objective after 69 iterations = 23468.518016975428
# MSE after 69 iterations = 2.7797299232026496
# Objective after 70 iterations = 23468.506229480714
# MSE after 70 iterations = 2.779729994217799
# Objective after 71 iterations = 23468.495195167692
# MSE after 71 iterations = 2.77973006072056
# Objective after 72 iterations = 23468.48486571071
# MSE after 72 iterations = 2.7797301229972295
# Objective after 73 iterations = 23468.475195909195
# MSE after 73 iterations = 2.7797301813162654

# %%
alpha_ = alpha

# %%
validMSE = 0
for u,g,d in hoursValid:
    r = d['hours_transformed']
    bu = 0
    bi = 0
    if u in betaU:
        bu = betaU[u]
    if g in betaI:
        bi = betaI[g]
    prediction = alpha + bu + bi
    validMSE += (r - prediction)**2

validMSE /= len(hoursValid)
print("Validation MSE = " + str(validMSE))
# Out:
# Validation MSE = 3.3246508938026187

# %%
answers['Q8'] = (5.0, validMSE)
answers['Q8']
# Out:
# (5.0, 3.3246508938026187)

# %%
assertFloatList(answers['Q8'], 2)

# %%
predictions = open("predictions_Hours.csv", 'w')
for l in open("pairs_Hours.csv"):
    if l.startswith("userID"):
        predictions.write(l)
        continue
    u,g = l.strip().split(',')
    bu = 0
    bi = 0
    if u in betaU:
        bu = betaU[u]
    if g in betaI:
        bi = betaI[g]
    _ = predictions.write(u + ',' + g + ',' + str(alpha + bu + bi) + '\n')

predictions.close()

# %%
f = open("answers_hw3.txt", 'w')
f.write(str(answers) + '\n')
f.close()
